# %% [markdown]
# ＃ビュッフェ形式を再現してみる

# %%
#defining the libraries and the environment variables
import os
from dotenv import load_dotenv
import openai
import pandas as pd
import numpy as np
import re
import random

load_dotenv()

API_KEY = os.environ.get("OPENAI_API_KEY")
#print(API_KEY)
openai.api_key = API_KEY

pd.set_option('display.max_colwidth', None)

# %%
#define role
attribute_list = ["College student", "Graduate student", "College teacher"]
sex_list = ["male", "female"]
fisique_list = ["fat", "normal", "skinny"]

# %%
prompt="During a lunch break, you are in the college cafeteria where various meal options are available. Please choose your lunch.\n\
You don't have to choose from the entire menu.Please think about how much you eat and take the right amount.\n\
When responding, please consider each option independently to ensure your selection is based solely on your preference.\n\
Answer only the menu you chose.\n\
"

# %%
choice_1 = "Dynamite chili and tangy lime-seasoned beets"
choice_2 = "Beets"
choice_3 = "Lighter-choice beets with no added sugar"
choice_4 = "High-antioxidant beets"

choice_list = [choice_1, choice_2, choice_3, choice_4]

# %%
def generate_completion(role, choice, prompt):
    response = openai.ChatCompletion.create(
        model="gpt-4-turbo-2024-04-09",
        #model="gpt-3.5-turbo-1106",
        messages=[
            {"role": "system", "content": role},
            {"role": "user", "content": f"{prompt},{choice}"}
        ],
        temperature=0.7,
        max_tokens=100,
        )
    return response

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page
url = "https://gakushoku.coop/search"

# Send HTTP request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Using the XPath provided as reference to create a similar BeautifulSoup search.
    # Let's break the XPath to guess the CSS selectors: '//*[@id="__next"]/section/div/div[3]/div[2]/div/section/ul/li[1]/div[2]/a/p[2]'
    # This can be roughly translated to CSS Selector: '#__next > section > div > div:nth-child(3) > div:nth-child(2) > div > section > ul > li:nth-child(1) > div:nth-child(2) > a > p:nth-child(2)'
    # You might need to adjust the selector based on actual page content.
    element = soup.select_one('#__next > section > div > div:nth-child(3) > div:nth-child(2) > div > section > ul > li:nth-child(1) > div:nth-child(2) > a > p:nth-child(2)')
    
    if element:
        # Print the text of the element
        print(element.text)
    else:
        print("Element not found.")
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# Element not found.

# %%
import random

class Buffet_Stanford:
    def __init__(self):
        self.choice_1 = "Dynamite chili and tangy lime-seasoned beets"
        self.choice_2 = "Beets"
        self.choice_3 = "Lighter-choice beets with no added sugar"
        self.choice_4 = "High-antioxidant beets"
        self.choice_list = [self.choice_1, self.choice_2, self.choice_3, self.choice_4]

        self.class_1 = "Main dish"
        self.class_2 = "Side dish, Salad"
        self.class_3 = "Rice"
        self.class_4 = "Noodles"
        
        # Main dish
        self.food_1 = [
            "Blackended Tilapia",#ブラックエンドティラピア
            "Cajun Chick'n",#ケイジャンチキン
            "Homestyle Collard Greens",#ホームスタイルコリアンダー
            "Seasonal Steamed Vegetables",#季節の蒸し野菜
            "Dirty Rice",#ダーティライス
            "Cheesy Grits",#チーズグリッツ
            "Meat Lover's Pizza",#ミートラバーズピザ
            "Cheese Pizza",#チーズピザ
            "Allergy Friendly PizzaCrust",#アレルギーフレンドリーピザクラスト
            "Homestyle Chicken Soup",#ホームスタイルチキンスープ
            "Minestorone Soup",#ミネストローネスープ
            "Performance Bar",#パフォーマンスバー
            "Pasta Marinara",#パスタマリナーラ
        ]
        # Noodles


    def generate_buffet_prompt(self):
        random_choice = "Dynamite chili and tangy lime-seasoned beets"#random.choice(self.choice_list)
        self.food_1.append(random_choice)

        # Shuffle each food category list to randomize their order
        random.shuffle(self.food_1)

        buffet_prompt = f"{self.class_1}\n" + "\n".join(f"{idx+1}. {dish}" for idx, dish in enumerate(self.food_1)) + "\n" \

        return buffet_prompt, random_choice

# Instance creation and function call
buffet_st = Buffet_Stanford()
buffet_prompt, choice = buffet_st.generate_buffet_prompt()
print(buffet_prompt)
print("\nChosen Beet Dish:", choice)
# Out:
# Main dish
# 1. Cajun Chick'n
# 2. Blackended Tilapia
# 3. Homestyle Chicken Soup
# 4. Dynamite chili and tangy lime-seasoned beets
# 5. Minestorone Soup
# 6. Seasonal Steamed Vegetables
# 7. Performance Bar
# 8. Cheesy Grits
# 9. Allergy Friendly PizzaCrust
# 10. Cheese Pizza
# 11. Dirty Rice
# 12. Homestyle Collard Greens
# 13. Pasta Marinara
# 14. Meat Lover's Pizza
#
#
# Chosen Beet Dish: Dynamite chili and tangy lime-seasoned beets

# %%
import random

class Buffet_UTokyo:
    def __init__(self):
        self.choice_1 = "Dynamite chili and tangy lime-seasoned beets"
        self.choice_2 = "Beets"
        self.choice_3 = "Lighter-choice beets with no added sugar"
        self.choice_4 = "High-antioxidant beets"
        self.choice_list = [self.choice_1, self.choice_2, self.choice_3, self.choice_4]

        self.class_1 = "Main dish"
        self.class_2 = "Side dish, Salad"
        self.class_3 = "Rice"
        self.class_4 = "Noodles"
        
        # Main dish
        self.food_1 = [
            "Deep-fried succulent chicken",#手仕込みジューシー唐揚げ
            "Hamburger steak with arrabbiata sauce",#スパイシートマトハンバーグ
        #    "Grilled chicken with salt-based sauce",#グリルチキン（塩だれ）
            "Salt-grilled mackerel"#さば塩焼き
        ]
        # Side dish, Salad
        self.food_2 = [
        #    "French fries Spicy",#フライドポテト（スパイシー）
        #    "Soft-boiled egg",#温泉たまご
            "Boiled spinach",#ほうれん草のおひたし
            "Boiled chopped okura",#オクラのおひたし
            "Soy sauce taste boiled dried daikon radish strips",#切り干し大根
        #    "Tuna salad (with boiled egg, wakame seaweed, and shredded cabbage)",#ツナサラダ
        #    "Macaroni and corn salad (with wakame seaweed and shredded cabbage)"#マカロニ＆コーンサラダ
        ]
        # Rice
        self.food_3 = [
            "(Small size) Rice",#ごはん(小)
            "(Medium size) Rice",#ごはん(中)
            "(Large size) Rice"#ごはん(大)
        ]
        # Noodles
        self.food_4 = [
            "Plain udon noodles",#かけうどん
            "Zaru soba cool soba noodles",#ざるそば
            "Ramen in soy-sauce flavored soup"#醤油ラーメン
        ]

    def generate_buffet_prompt(self):
        random_choice = "Dynamite chili and tangy lime-seasoned beets"#random.choice(self.choice_list)
        self.food_2.append(random_choice)

        # Shuffle each food category list to randomize their order
        random.shuffle(self.food_1)
        random.shuffle(self.food_2)
        random.shuffle(self.food_3)
        random.shuffle(self.food_4)

        
        buffet_prompt = f"{self.class_1}\n" + "\n".join(f"{idx+1}. {dish}" for idx, dish in enumerate(self.food_1)) + "\n" \
                         f"{self.class_2}\n" + "\n".join(f"{idx+1}. {dish}" for idx, dish in enumerate(self.food_2)) + "\n" \
                         f"{self.class_3}\n" + "\n".join(f"{idx+1}. {dish}" for idx, dish in enumerate(self.food_3)) + "\n" \
                         f"{self.class_4}\n" + "\n".join(f"{idx+1}. {dish}" for idx, dish in enumerate(self.food_4))
        
        return buffet_prompt, random_choice

# Instance creation and function call
buffet_ut = Buffet_UTokyo()
buffet_prompt, choice = buffet_ut.generate_buffet_prompt()
print(buffet_prompt)
print("\nChosen Beet Dish:", choice)
# Out:
# Main dish
# 1. Salt-grilled mackerel
# 2. Hamburger steak with arrabbiata sauce
# 3. Deep-fried succulent chicken
# Side dish, Salad
# 1. Boiled chopped okura
# 2. Dynamite chili and tangy lime-seasoned beets
# 3. Soy sauce taste boiled dried daikon radish strips
# 4. Boiled spinach
# Rice
# 1. (Large size) Rice
# 2. (Small size) Rice
# 3. (Medium size) Rice
# Noodles
# 1. Ramen in soy-sauce flavored soup
# 2. Plain udon noodles
# 3. Zaru soba cool soba noodles
#
# Chosen Beet Dish: Dynamite chili and tangy lime-seasoned beets

# %%
def buffet_vegetable_preference(prompt,range_number):
    df = pd.DataFrame()
    
    for i in range(range_number):
        attribute = "college student"
        #attribute = random.choice(attribute_list)

        role = f"you are {attribute}."
        #you have to behave like {attribute}."

        buffet_prompt, selected_choice = buffet_ut.generate_buffet_prompt()

        response = generate_completion(role, buffet_prompt, prompt)
        content = response.choices[0].message.content

        #extract number from responce
        vegetable_selected = choice_1.lower() in content or choice_1 in content
        df_sample = pd.DataFrame({"attribute":attribute,"response":content,"number":vegetable_selected,"selected_vegetable":selected_choice},index=[0])

        df = pd.concat([df,df_sample],ignore_index=True)
    return df

# %%
df_1 = buffet_vegetable_preference(prompt,30)
#df_2 = buffet_vegetable_preference(choice_2,prompt,50)
df_1.head(30)
# Out:
#           attribute
# 0   college student  \
# 1   college student
# 2   college student
# 3   college student
# 4   college student
# 5   college student
# 6   college student
# 7   college student
# 8   college student
# 9   college student
# 10  college student
# 11  college student
# 12  college student
# 13  college student
# 14  college student
# 15  college student
# 16  college student
# 17  college student
# 18  college student
# 19  college student
# 20  college student
# 21  college student
# 22  college student
# 23  college student
# 24  college student
# 25  college student
# 26  college student
# 27  college student
# 28  college student
# 29  college student
#
#                                                                                                                                                                                                  response
# 0                                                                                                 Hamburger steak with arrabbiata sauce\nDynamite chili and tangy lime-seasoned beets\n(Medium size) Rice  \
# 1   I'll go with the salt-grilled mackerel for the main dish. For the side dish, I'll have the boiled spinach. I'd like a medium size rice, and for noodles, I'll choose the zaru soba cool soba noodles.
# 2                                                                                     I'll have the deep-fried succulent chicken for my main dish, with a side of boiled spinach, and a medium size rice.
# 3                                                                                                                   Main dish: Salt-grilled mackerel\nSide dish: Boiled spinach\nRice: (Medium size) Rice
# 4                                                                                Main dish: Salt-grilled mackerel\nSide dish: Soy sauce taste boiled dried daikon radish strips\nRice: (Medium size) Rice
# 5                                                                                                                               Hamburger steak with arrabbiata sauce\nBoiled spinach\n(Medium size) Rice
# 6                                                                                            Main dish: 2. Deep-fried succulent chicken\nSide dish, Salad: 4. Boiled spinach\nRice: 3. (Medium size) Rice
# 7                                                                                                            Main dish: Deep-fried succulent chicken\nSide dish: Boiled spinach\nRice: (Medium size) Rice
# 8                                                                 Main dish: 3. Salt-grilled mackerel\nSide dish: 13. Boiled spinach\nRice: 2. (Small size) Rice\nNoodles: 3. Zaru soba cool soba noodles
# 9                                                                                                                                               Salt-grilled mackerel\nBoiled spinach\n(Medium size) Rice
# 10                                                               Main dish: 2. Deep-fried succulent chicken\nSide dish: 12. Soy sauce taste boiled dried daikon radish strips\nRice: 1. (Small size) Rice
# 11                                                                              I will choose the deep-fried succulent chicken as the main dish, boiled spinach as the side dish, and a medium size rice.
# 12                                                                                            I'll have the salt-grilled mackerel as my main dish, boiled chopped okura as a side, and a small size rice.
# 13                                                                                     I'll have the deep-fried succulent chicken as my main dish, with a side of boiled spinach, and a medium size rice.
# 14                                                                                                                              Hamburger steak with arrabbiata sauce\nBoiled spinach\n(Medium size) Rice
# 15                                                                              I'll choose the deep-fried succulent chicken for the main dish, boiled spinach for the side dish, and a medium size rice.
# 16                                                                      Main dish: 2. Salt-grilled mackerel\nSide dish: 18. Soy sauce taste boiled dried daikon radish strips\nRice: 3. (Small size) Rice
# 17                                                                                  I'll choose the deep-fried succulent chicken as my main dish, boiled spinach as my side dish, and a medium size rice.
# 18                                                          I'll have the salt-grilled mackerel as the main dish. For the side dish, I'll choose the boiled spinach. I'll also have the medium size rice.
# 19                                                                                                  Main dish: 2. Salt-grilled mackerel\nSide dish, Salad: 7. Boiled spinach\nRice: 3. (Medium size) Rice
# 20                                                                                       I'll choose the salt-grilled mackerel for the main dish, boiled spinach as the side dish, and a small size rice.
# 21                                                                                             I'll have the salt-grilled mackerel as the main dish, boiled spinach for the side, and a medium size rice.
# 22                                              Main dish: 2. Deep-fried succulent chicken\n\nSide dish: 6. Boiled chopped okura\n\nRice: 1. (Small size) Rice\n\nNoodles: 1. Zaru soba cool soba noodles
# 23                                                                             Main dish: Deep-fried succulent chicken\nSide dish: Dynamite chili and tangy lime-seasoned beets\nRice: (Medium size) Rice
# 24                                                                      Main dish: Salt-grilled mackerel\n\nSide dish: Boiled spinach\n\nRice: (Medium size) Rice\n\nNoodles: Zaru soba cool soba noodles
# 25                                                                                                                                                                                  Salt-grilled mackerel
# 26                                                    Main dish: 2. Deep-fried succulent chicken\nSide dish: 26. Boiled spinach\nRice: 2. (Small size) Rice\nNoodles: 3. Ramen in soy-sauce flavored soup
# 27                                                                                         I'll have the salt-grilled mackerel as the main dish, boiled spinach as the side dish, and a medium size rice.
# 28                                                                                                                                                                           Deep-fried succulent chicken
# 29                                                                                                                                                                  Hamburger steak with arrabbiata sauce
#
#     number                            selected_vegetable
# 0     True  Dynamite chili and tangy lime-seasoned beets
# 1    False  Dynamite chili and tangy lime-seasoned beets
# 2    False  Dynamite chili and tangy lime-seasoned beets
# 3    False  Dynamite chili and tangy lime-seasoned beets
# 4    False  Dynamite chili and tangy lime-seasoned beets
# 5    False  Dynamite chili and tangy lime-seasoned beets
# 6    False  Dynamite chili and tangy lime-seasoned beets
# 7    False  Dynamite chili and tangy lime-seasoned beets
# 8    False  Dynamite chili and tangy lime-seasoned beets
# 9    False  Dynamite chili and tangy lime-seasoned beets
# 10   False  Dynamite chili and tangy lime-seasoned beets
# 11   False  Dynamite chili and tangy lime-seasoned beets
# 12   False  Dynamite chili and tangy lime-seasoned beets
# 13   False  Dynamite chili and tangy lime-seasoned beets
# 14   False  Dynamite chili and tangy lime-seasoned beets
# 15   False  Dynamite chili and tangy lime-seasoned beets
# 16   False  Dynamite chili and tangy lime-seasoned beets
# 17   False  Dynamite chili and tangy lime-seasoned beets
# 18   False  Dynamite chili and tangy lime-seasoned beets
# 19   False  Dynamite chili and tangy lime-seasoned beets
# 20   False  Dynamite chili and tangy lime-seasoned beets
# 21   False  Dynamite chili and tangy lime-seasoned beets
# 22   False  Dynamite chili and tangy lime-seasoned beets
# 23    True  Dynamite chili and tangy lime-seasoned beets
# 24   False  Dynamite chili and tangy lime-seasoned beets
# 25   False  Dynamite chili and tangy lime-seasoned beets
# 26   False  Dynamite chili and tangy lime-seasoned beets
# 27   False  Dynamite chili and tangy lime-seasoned beets
# 28   False  Dynamite chili and tangy lime-seasoned beets
# 29   False  Dynamite chili and tangy lime-seasoned beets

# %%
x = 1
y = 2
result = x or y
print(result)

result = x | y
print(result)
# Out:
# 1
# 3

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define dictionaries to map numeric values to descriptive labels
choice_1_dic = {
    1: "Dynamite chili and \n tangy lime-seasoned beets",
    2: "Beets",
    3: "Lighter-choice beets \n with no added sugar",
    4: "High-antioxidant beets"
}

choice_2_dic = {
    1:"Beets",
    2:"Dynamite chili and \n tangy lime-seasoned beets",
    3:"Lighter-choice beets \n with no added sugar",
    4:"High-antioxidant beets"
}


choice_3_dic = {
    1:"Higher-antioxidant beets",
    2:"Beets",
    3:"Lighter-choice beets \n with no added sugar",
    4:"Dynamite chili and \n tangy lime-seasoned beets"
}

column = "number"

# Define a function to plot frequency of numbers associated with descriptive labels
def plot_frequency(df,column,choice_dic, ax):
    frequency = df[column].value_counts().sort_index()
    frequency.index = frequency.index.map(lambda x: choice_dic[x])
    desired_order = list(choice_1_dic.values())
    frequency = frequency.reindex(desired_order)
    frequency.plot(kind='bar', ax=ax)
    ax.set_xlabel('label')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Frequency of {column}')
    ax.tick_params(axis='x', rotation=0)

# Create DataFrame 1 (df_1) and DataFrame 2 (df_2) before calling this function

# Plot frequency for DataFrame 1
plt.figure(figsize=(15, 6))
ax1 = plt.subplot(1, 3, 1)
plot_frequency(df_1, column,choice_1_dic, ax1)

# Plot frequency for DataFrame 2
ax2 = plt.subplot(1, 3, 2)
plot_frequency(df_2, column,choice_2_dic, ax2)

#ax3 = plt.subplot(1, 3, 3)
#plot_frequency(df_3, column,choice_3_dic, ax3)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 46
#      44 plt.figure(figsize=(15, 6))
#      45 ax1 = plt.subplot(1, 3, 1)
# ---> 46 plot_frequency(df_1, column,choice_1_dic, ax1)
#      48 # Plot frequency for DataFrame 2
#      49 ax2 = plt.subplot(1, 3, 2)
#
# Cell In[13], line 32, in plot_frequency(df, column, choice_dic, ax)
#      30 def plot_frequency(df,column,choice_dic, ax):
#      31     frequency = df[column].value_counts().sort_index()
# ---> 32     frequency.index = frequency.index.map(lambda x: choice_dic[x])
#      33     desired_order = list(choice_1_dic.values())
#      34     frequency = frequency.reindex(desired_order)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:6158, in Index.map(self, mapper, na_action)
#    6138 """
#    6139 Map values using an input mapping or function.
#    6140
#    (...)
#    6154     a MultiIndex will be returned.
#    6155 """
#    6156 from pandas.core.indexes.multi import MultiIndex
# -> 6158 new_values = self._map_values(mapper, na_action=na_action)
#    6160 # we can return a MultiIndex
#    6161 if new_values.size and isinstance(new_values[0], tuple):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/base.py:924, in IndexOpsMixin._map_values(self, mapper, na_action)
#     921         raise ValueError(msg)
#     923 # mapper is a function
# --> 924 new_values = map_f(values, mapper)
#     926 return new_values
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[13], line 32, in plot_frequency.<locals>.<lambda>(x)
#      30 def plot_frequency(df,column,choice_dic, ax):
#      31     frequency = df[column].value_counts().sort_index()
# ---> 32     frequency.index = frequency.index.map(lambda x: choice_dic[x])
#      33     desired_order = list(choice_1_dic.values())
#      34     frequency = frequency.reindex(desired_order)
#
# KeyError: False
