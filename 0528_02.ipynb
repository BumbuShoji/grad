# %% [markdown]
# #コロナ禍での行動変容の効果をLLMで再現できるか調べる\n
# ##実装する機能
# ・プロンプト入力
# ・プロンプト回答
# ・集計
# ・表作成

# %%
#import libraries
import os
from dotenv import load_dotenv
from openai import OpenAI
import pandas as pd
import numpy as np
import re
import random
import matplotlib.pyplot as plt
import ast
import json
from collections import Counter


client = OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY")
    )
pd.set_option('display.max_colwidth', None)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
def generate_completion(role, prompt,questionaire):
    response = client.chat.completions.create(
        model="gpt-4o",
        #model="gpt-3.5-turbo-1106",
        messages=[
            {"role": "system", "content": role},
            {"role": "user", "content": f"{prompt},\n{questionaire}"}
        ],
        temperature=0.2,
        max_tokens=1000,
        )
    return response

# %%
#make role
age_list=["20-29","30-39","40-49","50-59","60-64"]
sex_list=["male","female"]
age="20-29" #random.choice(age_list)
sex="male" #random.choice(sex_list)


#role = f"Act as a person with the following attributes. {random.choice(age_list)} years old, {random.choice(sex_list)}."
role =f"You are a person who is {age} years old,{sex}"
#make prompt
prompt="Understanding Your Attitude Towards Covid-19 Prevention\n\
We invite you to participate in this questionnaire to help us gain insights into your attitudes and behaviors regarding Covid-19 prevention. Your responses will be invaluable in shaping effective public health strategies.\n\
Instructions:\n\
・Carefully consider each question independently.\n\
・Select the option that best reflects your current situation and personal views.\n\
・Answer each question based solely on your own experiences and beliefs.\n\
Answer Format Example:\n\
Go shopping everyday\n\
['1.Very true']\n\
Thank you for your participation."

#make options
options_list=["1.Very true","2.True","3.Neither","4.Not true","5.Not at all"]
questions_list=["Avoid a poorly-ventilated closed space",
"Avoid large gatherings",
"Avoid conversations or shouting in close proximity",
"Avoid places where items 1-3 above overlap",
"Do not go to dinner with friends",
"Do not go to mass gatherings",
"Participate in virtual events using online tools",
"Undertake frequent handwashing",
"Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)",
"Disinfect things around",
"Avoid going out when you have a cold",
"Avoid going to clinic even when having a cold symptom",
"Prepare consultation and transportation methods for when you feel ill",
"Always wear a surgical-style mask when going out",
"Stockpile surgical-style masks",
"Stockpile food, toilet paper, tissue paper, etc.",
"Avoid contact with younger people",
"Avoid contact with older people",
"Get sufficient rest and sleep",
"Eat a nutritious diet",
"Do exercise such as jogging or exercise using DVD"]

#make questionaire
questionaire=""
for i in range(len(questions_list)):
    questionaire+=f"{questions_list[i]}\n{options_list}\n\n"

def get_answer(content) -> dict[str:str]:
    pattern = re.compile(r"\['(.*?)'\]")
    answers = pattern.findall(content)
    answers_dict = dict(zip(questions_list,answers))
    return answers_dict

response = generate_completion(role,prompt,questionaire)
content=response.choices[0].message.content
answers=get_answer(content)
print(type(answers))
print(answers)
# Out:
# <class 'dict'>
# {'Avoid a poorly-ventilated closed space': '1.Very true', 'Avoid large gatherings': '1.Very true', 'Avoid conversations or shouting in close proximity': '1.Very true', 'Avoid places where items 1-3 above overlap': '1.Very true', 'Do not go to dinner with friends': '2.True', 'Do not go to mass gatherings': '1.Very true', 'Participate in virtual events using online tools': '2.True', 'Undertake frequent handwashing': '1.Very true', 'Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)': '1.Very true', 'Disinfect things around': '2.True', 'Avoid going out when you have a cold': '1.Very true', 'Avoid going to clinic even when having a cold symptom': '4.Not true', 'Prepare consultation and transportation methods for when you feel ill': '2.True', 'Always wear a surgical-style mask when going out': '1.Very true', 'Stockpile surgical-style masks': '2.True', 'Stockpile food, toilet paper, tissue paper, etc.': '2.True', 'Avoid contact with younger people': '4.Not true', 'Avoid contact with older people': '2.True', 'Get sufficient rest and sleep': '1.Very true', 'Eat a nutritious diet': '2.True', 'Do exercise such as jogging or exercise using DVD': '3.Neither'}

# %%
def generate_data(count)->pd.DataFrame:
    global age_list, sex_list, prompt, questionaire
    data = []
    #generate completion
    for i in range(count):
        age=random.choice(age_list)
        sex=random.choice(sex_list)
        #role = f"Act as a person with the following attributes. {random.choice(age_list)} years old, {random.choice(sex_list)}."
        role =f"You are a person who is {age} years old,{sex}"
        response = generate_completion(role, prompt,questionaire)
        content = response.choices[0].message.content
        answers = get_answer(content)
        u_40 = 0 if age in ["20-29","30-39"] else 1
        new_data = {"age":age,"u_40":u_40,"sex":sex,"content":content}
        new_data.update(answers)
        data.append(new_data)

    df_data = pd.DataFrame(data)
    return df_data

# %%
import pandas as pd
# aggregate data
def aggregate_data(df_data):
    global questions_list, options_list
    #aggregate data
    data_aggregate =[]
    for question in questions_list:
        for option in options_list:
            count = df_data[question].str.contains(option).sum()
            data_aggregate.append({"question":question,"option":option,"count":count})

    df_aggregate = pd.DataFrame(data_aggregate)
    # Pivot the DataFrame
    df_aggregate_pivot = df_aggregate.pivot(index='question', columns='option', values='count')

    # Fill NaN with 0 (if any)
    df_aggregate_pivot = df_aggregate_pivot.fillna(0)
    return df_aggregate_pivot

# %%
def separate_dataframes(df_data, filter_list, filter_column):
    """
    Separate the DataFrame based on the unique values in the specified column.

    Parameters:
    df_data (pd.DataFrame): The input DataFrame.
    filter_list (list): The list of unique values to filter by.
    filter_column (str): The column to filter on.

    Returns:
    dict: A dictionary of DataFrames filtered by the specified column values.
    """
    df_data_dict = {}
    for value in filter_list:
        df_data_dict[f'df_data_{value}'] = df_data[df_data[filter_column] == value]
    return df_data_dict

# %%
import pandas as pd

def aggregate_dataframes(df_data_dict):

    # Create an iterator from the dictionary items
    dict_iterator = iter(df_data_dict.items())

    # Retrieve values one by one
    try:
        key,value = next(dict_iterator)
        df_aggregate_1 = aggregate_data(value)

        key,value = next(dict_iterator)
        df_aggregate_2 = aggregate_data(value)

        # Continue calling next(dict_iterator) as needed
    except StopIteration:
        print("No more items in the dictionary.")
    return df_aggregate_1,df_aggregate_2

def calculate_ratio(df_aggregate,attribute):
    df_aggregate[f"Ratio of true:{attribute}"] = (df_aggregate["1.Very true"] + df_aggregate["2.True"])/df_aggregate.sum(axis=1)
    return df_aggregate[f"Ratio of true:{attribute}"]

# %%
number_of_sample = 50
df_data = generate_data(number_of_sample)

df_data_dict_sex = separate_dataframes(df_data,sex_list,"sex")
df_data_dict_age = separate_dataframes(df_data,[0,1],"u_40")

df_aggregate = aggregate_data(df_data)

df_male_aggregate,df_female_aggregate = aggregate_dataframes(df_data_dict_sex)
df_u40_aggregate,df_o40_aggregate = aggregate_dataframes(df_data_dict_age)

dataframes_to_process = {
    "all":df_aggregate,
    "male":df_male_aggregate,
    "female":df_female_aggregate,
    "u40":df_u40_aggregate,
    "o40":df_o40_aggregate
}

# Calculate ratios for each DataFrame
ratios = [calculate_ratio(df,key) for key,df in dataframes_to_process]

# Concatenate the resulting DataFrames
df_ratio_unif = pd.concat(ratios, axis=1)

df_ratio_unif.head(21)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 9
#       5 df_data_dict_age = separate_dataframes(df_data,[0,1],"u_40")
#       7 df_aggregate = aggregate_data(df_data)
# ----> 9 df_male_aggregate,df_female_aggregate = aggregate_dataframes(df_data_dict_sex)
#      10 df_u40_aggregate,df_o40_aggregate = aggregate_dataframes(df_data_dict_age)
#      12 dataframes_to_process = [
#      13     df_aggregate,
#      14     df_male_aggregate,
#    (...)
#      17     df_o40_aggregate
#      18 ]
#
# Cell In[73], line 11, in aggregate_dataframes(df_data_dict)
#       9 try:
#      10     value = next(dict_iterator)
# ---> 11     df_aggregate_1 = aggregate_data(value)
#      13     value = next(dict_iterator)
#      14     df_aggregate_2 = aggregate_data(value)
#
# Cell In[71], line 9, in aggregate_data(df_data)
#       7 for question in questions_list:
#       8     for option in options_list:
# ----> 9         count = df_data[question].str.contains(option).sum()
#      10         data_aggregate.append({"question":question,"option":option,"count":count})
#      12 df_aggregate = pd.DataFrame(data_aggregate)
#
# TypeError: tuple indices must be integers or slices, not str

# %%
dataframes_to_process = {
    "all":df_aggregate,
    "male":df_male_aggregate,
    "female":df_female_aggregate,
    "u40":df_u40_aggregate,
    "o40":df_o40_aggregate
}

# Calculate ratios for each DataFrame
ratios = [calculate_ratio(df,key) for key,df in dataframes_to_process.items()]

# Concatenate the resulting DataFrames
df_ratio_unif = pd.concat(ratios, axis=1)

df_ratio_unif.head(21)
# Out:
#                                                                            Ratio of true:all
# question
# Always wear a surgical-style mask when going out                                    0.962237  \
# Avoid a poorly-ventilated closed space                                              0.962237
# Avoid contact with older people                                                     0.681183
# Avoid contact with younger people                                                   0.000000
# Avoid conversations or shouting in close proximity                                  0.962237
# Avoid going out when you have a cold                                                0.962237
# Avoid going to clinic even when having a cold symptom                               0.000000
# Avoid large gatherings                                                              0.962237
# Avoid places where items 1-3 above overlap                                          0.962237
# Disinfect things around                                                             0.962237
# Do exercise such as jogging or exercise using DVD                                   0.737894
# Do not go to dinner with friends                                                    0.850561
# Do not go to mass gatherings                                                        0.962237
# Eat a nutritious diet                                                               0.962237
# Get sufficient rest and sleep                                                       0.962237
# Participate in virtual events using online tools                                    0.962237
# Prepare consultation and transportation methods for when you feel ill               0.813116
# Stockpile food, toilet paper, tissue paper, etc.                                    0.962237
# Stockpile surgical-style masks                                                      0.962237
# Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)           0.962237
# Undertake frequent handwashing                                                      0.962237
#
#                                                                            Ratio of true:male
# question
# Always wear a surgical-style mask when going out                                     0.930869  \
# Avoid a poorly-ventilated closed space                                               0.930869
# Avoid contact with older people                                                      0.795889
# Avoid contact with younger people                                                    0.000000
# Avoid conversations or shouting in close proximity                                   0.930869
# Avoid going out when you have a cold                                                 0.930869
# Avoid going to clinic even when having a cold symptom                                0.000000
# Avoid large gatherings                                                               0.930869
# Avoid places where items 1-3 above overlap                                           0.930869
# Disinfect things around                                                              0.930869
# Do exercise such as jogging or exercise using DVD                                    0.795889
# Do not go to dinner with friends                                                     0.727362
# Do not go to mass gatherings                                                         0.930869
# Eat a nutritious diet                                                                0.930869
# Get sufficient rest and sleep                                                        0.930869
# Participate in virtual events using online tools                                     0.930869
# Prepare consultation and transportation methods for when you feel ill                0.692834
# Stockpile food, toilet paper, tissue paper, etc.                                     0.930869
# Stockpile surgical-style masks                                                       0.930869
# Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)            0.930869
# Undertake frequent handwashing                                                       0.930869
#
#                                                                            Ratio of true:female
# question
# Always wear a surgical-style mask when going out                                       0.925720  \
# Avoid a poorly-ventilated closed space                                                 0.925720
# Avoid contact with older people                                                        0.518746
# Avoid contact with younger people                                                      0.000000
# Avoid conversations or shouting in close proximity                                     0.925720
# Avoid going out when you have a cold                                                   0.925720
# Avoid going to clinic even when having a cold symptom                                  0.000000
# Avoid large gatherings                                                                 0.925720
# Avoid places where items 1-3 above overlap                                             0.925720
# Disinfect things around                                                                0.925720
# Do exercise such as jogging or exercise using DVD                                      0.632433
# Do not go to dinner with friends                                                       0.925720
# Do not go to mass gatherings                                                           0.925720
# Eat a nutritious diet                                                                  0.925720
# Get sufficient rest and sleep                                                          0.925720
# Participate in virtual events using online tools                                       0.925720
# Prepare consultation and transportation methods for when you feel ill                  0.889811
# Stockpile food, toilet paper, tissue paper, etc.                                       0.925720
# Stockpile surgical-style masks                                                         0.925720
# Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)              0.925720
# Undertake frequent handwashing                                                         0.925720
#
#                                                                            Ratio of true:u40
# question
# Always wear a surgical-style mask when going out                                    0.888187  \
# Avoid a poorly-ventilated closed space                                              0.888187
# Avoid contact with older people                                                     0.888187
# Avoid contact with younger people                                                   0.000000
# Avoid conversations or shouting in close proximity                                  0.888187
# Avoid going out when you have a cold                                                0.888187
# Avoid going to clinic even when having a cold symptom                               0.000000
# Avoid large gatherings                                                              0.888187
# Avoid places where items 1-3 above overlap                                          0.888187
# Disinfect things around                                                             0.888187
# Do exercise such as jogging or exercise using DVD                                   0.670570
# Do not go to dinner with friends                                                    0.726120
# Do not go to mass gatherings                                                        0.888187
# Eat a nutritious diet                                                               0.888187
# Get sufficient rest and sleep                                                       0.888187
# Participate in virtual events using online tools                                    0.888187
# Prepare consultation and transportation methods for when you feel ill               0.557032
# Stockpile food, toilet paper, tissue paper, etc.                                    0.888187
# Stockpile surgical-style masks                                                      0.888187
# Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)           0.888187
# Undertake frequent handwashing                                                      0.888187
#
#                                                                            Ratio of true:o40
# question
# Always wear a surgical-style mask when going out                                    0.947295
# Avoid a poorly-ventilated closed space                                              0.947295
# Avoid contact with older people                                                     0.553632
# Avoid contact with younger people                                                   0.000000
# Avoid conversations or shouting in close proximity                                  0.947295
# Avoid going out when you have a cold                                                0.947295
# Avoid going to clinic even when having a cold symptom                               0.000000
# Avoid large gatherings                                                              0.947295
# Avoid places where items 1-3 above overlap                                          0.947295
# Disinfect things around                                                             0.947295
# Do exercise such as jogging or exercise using DVD                                   0.739504
# Do not go to dinner with friends                                                    0.869938
# Do not go to mass gatherings                                                        0.947295
# Eat a nutritious diet                                                               0.947295
# Get sufficient rest and sleep                                                       0.947295
# Participate in virtual events using online tools                                    0.947295
# Prepare consultation and transportation methods for when you feel ill               0.895798
# Stockpile food, toilet paper, tissue paper, etc.                                    0.947295
# Stockpile surgical-style masks                                                      0.947295
# Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)           0.947295
# Undertake frequent handwashing                                                      0.947295

# %%
df_aggregate = aggregate_data(df_data)

df_male_aggregate,df_female_aggregate = aggregate_dataframes(df_data_dict_sex)
df_u40_aggregate,df_o40_aggregate = aggregate_dataframes(df_data_dict_age)

dataframes_to_process = [
    df_aggregate,
    df_male_aggregate,
    df_female_aggregate,
    df_u40_aggregate,
    df_o40_aggregate
]

# Calculate ratios for each DataFrame
ratios = [calculate_ratio(df) for df in dataframes_to_process]

# Concatenate the resulting DataFrames
df_ratio_unif = pd.concat(ratios, axis=1)

df_ratio_unif.head(21)
# Out:
#                                                                            Ratio of true
# question
# Always wear a surgical-style mask when going out                                    1.00  \
# Avoid a poorly-ventilated closed space                                              1.00
# Avoid contact with older people                                                     0.70
# Avoid contact with younger people                                                   0.00
# Avoid conversations or shouting in close proximity                                  1.00
# Avoid going out when you have a cold                                                1.00
# Avoid going to clinic even when having a cold symptom                               0.00
# Avoid large gatherings                                                              1.00
# Avoid places where items 1-3 above overlap                                          1.00
# Disinfect things around                                                             1.00
# Do exercise such as jogging or exercise using DVD                                   0.76
# Do not go to dinner with friends                                                    0.88
# Do not go to mass gatherings                                                        1.00
# Eat a nutritious diet                                                               1.00
# Get sufficient rest and sleep                                                       1.00
# Participate in virtual events using online tools                                    1.00
# Prepare consultation and transportation methods for when you feel ill               0.84
# Stockpile food, toilet paper, tissue paper, etc.                                    1.00
# Stockpile surgical-style masks                                                      1.00
# Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)           1.00
# Undertake frequent handwashing                                                      1.00
#
#                                                                            Ratio of true
# question
# Always wear a surgical-style mask when going out                                1.000000  \
# Avoid a poorly-ventilated closed space                                          1.000000
# Avoid contact with older people                                                 0.846154
# Avoid contact with younger people                                               0.000000
# Avoid conversations or shouting in close proximity                              1.000000
# Avoid going out when you have a cold                                            1.000000
# Avoid going to clinic even when having a cold symptom                           0.000000
# Avoid large gatherings                                                          1.000000
# Avoid places where items 1-3 above overlap                                      1.000000
# Disinfect things around                                                         1.000000
# Do exercise such as jogging or exercise using DVD                               0.846154
# Do not go to dinner with friends                                                0.769231
# Do not go to mass gatherings                                                    1.000000
# Eat a nutritious diet                                                           1.000000
# Get sufficient rest and sleep                                                   1.000000
# Participate in virtual events using online tools                                1.000000
# Prepare consultation and transportation methods for when you feel ill           0.730769
# Stockpile food, toilet paper, tissue paper, etc.                                1.000000
# Stockpile surgical-style masks                                                  1.000000
# Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)       1.000000
# Undertake frequent handwashing                                                  1.000000
#
#                                                                            Ratio of true
# question
# Always wear a surgical-style mask when going out                                1.000000  \
# Avoid a poorly-ventilated closed space                                          1.000000
# Avoid contact with older people                                                 0.541667
# Avoid contact with younger people                                               0.000000
# Avoid conversations or shouting in close proximity                              1.000000
# Avoid going out when you have a cold                                            1.000000
# Avoid going to clinic even when having a cold symptom                           0.000000
# Avoid large gatherings                                                          1.000000
# Avoid places where items 1-3 above overlap                                      1.000000
# Disinfect things around                                                         1.000000
# Do exercise such as jogging or exercise using DVD                               0.666667
# Do not go to dinner with friends                                                1.000000
# Do not go to mass gatherings                                                    1.000000
# Eat a nutritious diet                                                           1.000000
# Get sufficient rest and sleep                                                   1.000000
# Participate in virtual events using online tools                                1.000000
# Prepare consultation and transportation methods for when you feel ill           0.958333
# Stockpile food, toilet paper, tissue paper, etc.                                1.000000
# Stockpile surgical-style masks                                                  1.000000
# Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)       1.000000
# Undertake frequent handwashing                                                  1.000000
#
#                                                                            Ratio of true
# question
# Always wear a surgical-style mask when going out                                1.000000  \
# Avoid a poorly-ventilated closed space                                          1.000000
# Avoid contact with older people                                                 1.000000
# Avoid contact with younger people                                               0.000000
# Avoid conversations or shouting in close proximity                              1.000000
# Avoid going out when you have a cold                                            1.000000
# Avoid going to clinic even when having a cold symptom                           0.000000
# Avoid large gatherings                                                          1.000000
# Avoid places where items 1-3 above overlap                                      1.000000
# Disinfect things around                                                         1.000000
# Do exercise such as jogging or exercise using DVD                               0.733333
# Do not go to dinner with friends                                                0.800000
# Do not go to mass gatherings                                                    1.000000
# Eat a nutritious diet                                                           1.000000
# Get sufficient rest and sleep                                                   1.000000
# Participate in virtual events using online tools                                1.000000
# Prepare consultation and transportation methods for when you feel ill           0.600000
# Stockpile food, toilet paper, tissue paper, etc.                                1.000000
# Stockpile surgical-style masks                                                  1.000000
# Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)       1.000000
# Undertake frequent handwashing                                                  1.000000
#
#                                                                            Ratio of true
# question
# Always wear a surgical-style mask when going out                                1.000000
# Avoid a poorly-ventilated closed space                                          1.000000
# Avoid contact with older people                                                 0.571429
# Avoid contact with younger people                                               0.000000
# Avoid conversations or shouting in close proximity                              1.000000
# Avoid going out when you have a cold                                            1.000000
# Avoid going to clinic even when having a cold symptom                           0.000000
# Avoid large gatherings                                                          1.000000
# Avoid places where items 1-3 above overlap                                      1.000000
# Disinfect things around                                                         1.000000
# Do exercise such as jogging or exercise using DVD                               0.771429
# Do not go to dinner with friends                                                0.914286
# Do not go to mass gatherings                                                    1.000000
# Eat a nutritious diet                                                           1.000000
# Get sufficient rest and sleep                                                   1.000000
# Participate in virtual events using online tools                                1.000000
# Prepare consultation and transportation methods for when you feel ill           0.942857
# Stockpile food, toilet paper, tissue paper, etc.                                1.000000
# Stockpile surgical-style masks                                                  1.000000
# Undertake cough etiquette (use handkerchiefs or sleeves instead of hands)       1.000000
# Undertake frequent handwashing                                                  1.000000

# %%
#print(df_data_dict_sex)
dict_iterator = iter(df_data_dict_sex.items())


# Retrieve values one by one
try:
    key, value = next(dict_iterator)
    print(f"Key: {key}, Value:\n{value}\n")

    key, value = next(dict_iterator)
    print(f"Key: {key}, Value:\n{value}\n")

    # Continue calling next(dict_iterator) as needed
except StopIteration:
    print("No more items in the dictionary.")
# Out:
# Key: df_data_male, Value:
#       age  u_40   sex
# 0   40-49     1  male  \
# 1   50-59     1  male
# 2   40-49     1  male
# 4   20-29     0  male
# 6   40-49     1  male
# 8   30-39     0  male
# 9   20-29     0  male
# 10  30-39     0  male
# 14  50-59     1  male
# 16  50-59     1  male
# 17  30-39     0  male
# 19  30-39     0  male
# 22  40-49     1  male
# 23  20-29     0  male
# 24  30-39     0  male
# 26  50-59     1  male
# 29  50-59     1  male
# 30  60-64     1  male
# 37  40-49     1  male
# 38  50-59     1  male
# 40  30-39     0  male
# 41  20-29     0  male
# 42  60-64     1  male
# 43  20-29     0  male
# 45  40-49     1  male
# 49  30-39     0  male
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        content
# 0                               Thank you for providing the questionnaire. Here are my responses based on my current situation and personal views:\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['2.True']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['3.Neither']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['4.Not true']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nI hope this helps with your research. If you need any further information or clarification, please let me know.  \
# 1                                                                                                                            Sure, I'd be happy to participate in the questionnaire. Here are my responses:\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['1.Very true']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for the opportunity to share my views.
# 2                                                                                                                                                                                                                               Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['3.Neither']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for your participation.
# 4                                                                                                                                                                                                                                                                   Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['3.Neither']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['4.Not true']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']
# 6                                                                                                                                      Sure, here are my responses to the questionnaire:\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['1.Very true']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for the opportunity to participate in this questionnaire.
# 8                                                                                                                                                                                                Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for the opportunity to participate in this questionnaire.
# 9                                                                                                                                  Sure, I'd be happy to participate in the questionnaire. Here are my responses:\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['2.True']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['3.Neither']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['4.Not true']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for the opportunity to share my views!
# 10                                                                                                                                                   Sure, I'd be happy to participate. Here are my responses:\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['3.Neither']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['4.Not true']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['2.True']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['3.Neither']\n\nThank you for the opportunity to share my views.
# 14                                                                                                                                                                                                                            Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['1.Very true']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for your participation.
# 16                                                                                                                                                                                                                                                                   Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['3.Neither']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']
# 17                                                                                                                                                                                                                                                                 Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['1.Very true']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']
# 19                                                                                                                                                                                                                                                                      Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']
# 22                                                                                                          Sure, I'll provide my responses based on my personal experiences and beliefs.\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['2.True']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['3.Neither']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['4.Not true']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['1.Very true']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for the opportunity to participate in this questionnaire.
# 23                                                                                                               Sure, here are my responses based on my current situation and personal views:\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['2.True']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['3.Neither']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['4.Not true']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for the opportunity to participate in this questionnaire.
# 24                                                                                                                                                                                                                                                                      Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']
# 26                                                                                                                                                                                                                                                                   Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['3.Neither']
# 29                                                       Sure, I can provide my responses based on my personal views and experiences.\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['3.Neither']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['1.Very true']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for the opportunity to provide my input. I hope this helps in shaping effective public health strategies.
# 30                                                                                                                                                                                                                         Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['3.Neither']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['1.Very true']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for your participation.
# 37  Sure, I can provide my responses to the questionnaire based on my personal views and experiences. Here they are:\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['4.Not true']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for the opportunity to participate in this questionnaire. I hope my responses help in shaping effective public health strategies.
# 38                                        Sure, I'll provide my responses based on my personal experiences and beliefs.\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['2.True']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['3.Neither']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for the opportunity to participate in this questionnaire. I hope my responses help in shaping effective public health strategies.
# 40                                                                                                                                                                                                                                                                   Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['3.Neither']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']
# 41                                                                                                                                                    Sure, I'd be happy to participate. Here are my responses:\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['4.Not true']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nThank you for the opportunity to share my views.
# 42                                                                                                                                                                                                                                                              Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['3.Neither']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['1.Very true']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']
# 43                                                                                                                                     Sure, I'd be happy to participate in the questionnaire. Here are my responses:\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['2.True']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['3.Neither']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['2.True']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['3.Neither']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['4.Not true']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['2.True']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['3.Neither']\n\nThank you for the opportunity to share my views.
# 45                                                                   Thank you for inviting me to participate in this questionnaire. Here are my responses:\n\nAvoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['2.True']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['3.Neither']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['2.True']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['1.Very true']\n\nEat a nutritious diet\n['1.Very true']\n\nDo exercise such as jogging or exercise using DVD\n['2.True']\n\nI hope this information is helpful for your research. Thank you for the opportunity to contribute.
# 49                                                                                                                                                                                                                                                                     Avoid a poorly-ventilated closed space\n['1.Very true']\n\nAvoid large gatherings\n['1.Very true']\n\nAvoid conversations or shouting in close proximity\n['1.Very true']\n\nAvoid places where items 1-3 above overlap\n['1.Very true']\n\nDo not go to dinner with friends\n['2.True']\n\nDo not go to mass gatherings\n['1.Very true']\n\nParticipate in virtual events using online tools\n['2.True']\n\nUndertake frequent handwashing\n['1.Very true']\n\nUndertake cough etiquette (use handkerchiefs or sleeves instead of hands)\n['1.Very true']\n\nDisinfect things around\n['2.True']\n\nAvoid going out when you have a cold\n['1.Very true']\n\nAvoid going to clinic even when having a cold symptom\n['4.Not true']\n\nPrepare consultation and transportation methods for when you feel ill\n['3.Neither']\n\nAlways wear a surgical-style mask when going out\n['1.Very true']\n\nStockpile surgical-style masks\n['2.True']\n\nStockpile food, toilet paper, tissue paper, etc.\n['2.True']\n\nAvoid contact with younger people\n['3.Neither']\n\nAvoid contact with older people\n['2.True']\n\nGet sufficient rest and sleep\n['2.True']\n\nEat a nutritious diet\n['2.True']\n\nDo exercise such as jogging or exercise using DVD\n['3.Neither']
#
#    Avoid a poorly-ventilated closed space Avoid large gatherings
# 0                             1.Very true            1.Very true  \
# 1                             1.Very true            1.Very true
# 2                             1.Very true            1.Very true
# 4                             1.Very true            1.Very true
# 6                             1.Very true            1.Very true
# 8                             1.Very true            1.Very true
# 9                             1.Very true            1.Very true
# 10                            1.Very true            1.Very true
# 14                            1.Very true            1.Very true
# 16                            1.Very true            1.Very true
# 17                            1.Very true            1.Very true
# 19                            1.Very true            1.Very true
# 22                            1.Very true            1.Very true
# 23                            1.Very true            1.Very true
# 24                            1.Very true            1.Very true
# 26                            1.Very true            1.Very true
# 29                            1.Very true            1.Very true
# 30                            1.Very true            1.Very true
# 37                            1.Very true            1.Very true
# 38                            1.Very true            1.Very true
# 40                            1.Very true            1.Very true
# 41                            1.Very true            1.Very true
# 42                            1.Very true            1.Very true
# 43                            1.Very true            1.Very true
# 45                            1.Very true            1.Very true
# 49                            1.Very true            1.Very true
#
#    Avoid conversations or shouting in close proximity
# 0                                              2.True  \
# 1                                         1.Very true
# 2                                         1.Very true
# 4                                         1.Very true
# 6                                         1.Very true
# 8                                         1.Very true
# 9                                              2.True
# 10                                        1.Very true
# 14                                        1.Very true
# 16                                        1.Very true
# 17                                        1.Very true
# 19                                        1.Very true
# 22                                             2.True
# 23                                             2.True
# 24                                        1.Very true
# 26                                        1.Very true
# 29                                        1.Very true
# 30                                        1.Very true
# 37                                        1.Very true
# 38                                             2.True
# 40                                        1.Very true
# 41                                        1.Very true
# 42                                        1.Very true
# 43                                             2.True
# 45                                             2.True
# 49                                        1.Very true
#
#    Avoid places where items 1-3 above overlap
# 0                                 1.Very true  \
# 1                                 1.Very true
# 2                                 1.Very true
# 4                                 1.Very true
# 6                                 1.Very true
# 8                                 1.Very true
# 9                                 1.Very true
# 10                                1.Very true
# 14                                1.Very true
# 16                                1.Very true
# 17                                1.Very true
# 19                                1.Very true
# 22                                1.Very true
# 23                                1.Very true
# 24                                1.Very true
# 26                                1.Very true
# 29                                1.Very true
# 30                                1.Very true
# 37                                1.Very true
# 38                                1.Very true
# 40                                1.Very true
# 41                                1.Very true
# 42                                1.Very true
# 43                                1.Very true
# 45                                1.Very true
# 49                                1.Very true
#
#    Do not go to dinner with friends Do not go to mass gatherings  ...
# 0                         3.Neither                  1.Very true  ...  \
# 1                            2.True                  1.Very true  ...
# 2                            2.True                  1.Very true  ...
# 4                            2.True                  1.Very true  ...
# 6                            2.True                  1.Very true  ...
# 8                            2.True                  1.Very true  ...
# 9                         3.Neither                  1.Very true  ...
# 10                           2.True                  1.Very true  ...
# 14                           2.True                  1.Very true  ...
# 16                           2.True                  1.Very true  ...
# 17                           2.True                  1.Very true  ...
# 19                           2.True                  1.Very true  ...
# 22                           2.True                  1.Very true  ...
# 23                        3.Neither                  1.Very true  ...
# 24                           2.True                  1.Very true  ...
# 26                           2.True                  1.Very true  ...
# 29                           2.True                  1.Very true  ...
# 30                           2.True                  1.Very true  ...
# 37                           2.True                  1.Very true  ...
# 38                        3.Neither                  1.Very true  ...
# 40                           2.True                  1.Very true  ...
# 41                           2.True                  1.Very true  ...
# 42                           2.True                  1.Very true  ...
# 43                        3.Neither                  1.Very true  ...
# 45                        3.Neither                  1.Very true  ...
# 49                           2.True                  1.Very true  ...
#
#    Avoid going to clinic even when having a cold symptom
# 0                                             4.Not true  \
# 1                                             4.Not true
# 2                                             4.Not true
# 4                                             4.Not true
# 6                                             4.Not true
# ...
# 11                                        1.Very true
# 12                                        1.Very true
# 13                                        1.Very true
# 15                                        1.Very true
# 18                                        1.Very true
# 20                                        1.Very true
# 21                                        1.Very true
# 25                                        1.Very true
# 27                                        1.Very true
# 28                                        1.Very true
# 31                                        1.Very true
# 32                                        1.Very true
# 33                                        1.Very true
# 34                                        1.Very true
# 35                                        1.Very true
# 36                                        1.Very true
# 39                                        1.Very true
# 44                                        1.Very true
# 46                                        1.Very true
# 47                                        1.Very true
# 48                                        1.Very true
#
#    Avoid places where items 1-3 above overlap
# 3                                 1.Very true  \
# 5                                 1.Very true
# 7                                 1.Very true
# 11                                1.Very true
# 12                                1.Very true
# 13                                1.Very true
# 15                                1.Very true
# 18                                1.Very true
# 20                                1.Very true
# 21                                1.Very true
# 25                                1.Very true
# 27                                1.Very true
# 28                                1.Very true
# 31                                1.Very true
# 32                                1.Very true
# 33                                1.Very true
# 34                                1.Very true
# 35                                1.Very true
# 36                                1.Very true
# 39                                1.Very true
# 44                                1.Very true
# 46                                1.Very true
# 47                                1.Very true
# 48                                1.Very true
#
#    Do not go to dinner with friends Do not go to mass gatherings  ...
# 3                            2.True                  1.Very true  ...  \
# 5                            2.True                  1.Very true  ...
# 7                            2.True                  1.Very true  ...
# 11                           2.True                  1.Very true  ...
# 12                           2.True                  1.Very true  ...
# 13                           2.True                  1.Very true  ...
# 15                           2.True                  1.Very true  ...
# 18                           2.True                  1.Very true  ...
# 20                           2.True                  1.Very true  ...
# 21                           2.True                  1.Very true  ...
# 25                           2.True                  1.Very true  ...
# 27                           2.True                  1.Very true  ...
# 28                           2.True                  1.Very true  ...
# 31                           2.True                  1.Very true  ...
# 32                           2.True                  1.Very true  ...
# 33                           2.True                  1.Very true  ...
# 34                           2.True                  1.Very true  ...
# 35                           2.True                  1.Very true  ...
# 36                           2.True                  1.Very true  ...
# 39                           2.True                  1.Very true  ...
# 44                           2.True                  1.Very true  ...
# 46                           2.True                  1.Very true  ...
# 47                           2.True                  1.Very true  ...
# 48                           2.True                  1.Very true  ...
#
#    Avoid going to clinic even when having a cold symptom
# 3                                             4.Not true  \
# 5                                             4.Not true
# 7                                             4.Not true
# 11                                            4.Not true
# 12                                            4.Not true
# 13                                            4.Not true
# 15                                            4.Not true
# 18                                            4.Not true
# 20                                            4.Not true
# 21                                            4.Not true
# 25                                            4.Not true
# 27                                            4.Not true
# 28                                            4.Not true
# 31                                            4.Not true
# 32                                            4.Not true
# 33                                            4.Not true
# 34                                            4.Not true
# 35                                            4.Not true
# 36                                            4.Not true
# 39                                            4.Not true
# 44                                            4.Not true
# 46                                            4.Not true
# 47                                            4.Not true
# 48                                            4.Not true
#
#    Prepare consultation and transportation methods for when you feel ill
# 3                                                                 2.True  \
# 5                                                                 2.True
# 7                                                                 2.True
# 11                                                                2.True
# 12                                                             3.Neither
# 13                                                                2.True
# 15                                                                2.True
# 18                                                                2.True
# 20                                                                2.True
# 21                                                                2.True
# 25                                                                2.True
# 27                                                                2.True
# 28                                                                2.True
# 31                                                                2.True
# 32                                                                2.True
# 33                                                                2.True
# 34                                                                2.True
# 35                                                                2.True
# 36                                                                2.True
# 39                                                                2.True
# 44                                                                2.True
# 46                                                                2.True
# 47                                                                2.True
# 48                                                                2.True
#
#    Always wear a surgical-style mask when going out
# 3                                       1.Very true  \
# 5                                       1.Very true
# 7                                       1.Very true
# 11                                      1.Very true
# 12                                      1.Very true
# 13                                      1.Very true
# 15                                      1.Very true
# 18                                      1.Very true
# 20                                      1.Very true
# 21                                      1.Very true
# 25                                      1.Very true
# 27                                      1.Very true
# 28                                      1.Very true
# 31                                      1.Very true
# 32                                      1.Very true
# 33                                      1.Very true
# 34                                      1.Very true
# 35                                      1.Very true
# 36                                      1.Very true
# 39                                      1.Very true
# 44                                      1.Very true
# 46                                      1.Very true
# 47                                      1.Very true
# 48                                      1.Very true
#
#    Stockpile surgical-style masks
# 3                          2.True  \
# 5                          2.True
# 7                          2.True
# 11                         2.True
# 12                         2.True
# 13                         2.True
# 15                         2.True
# 18                         2.True
# 20                         2.True
# 21                         2.True
# 25                         2.True
# 27                         2.True
# 28                         2.True
# 31                         2.True
# 32                         2.True
# 33                         2.True
# 34                         2.True
# 35                         2.True
# 36                         2.True
# 39                         2.True
# 44                         2.True
# 46                         2.True
# 47                         2.True
# 48                         2.True
#
#    Stockpile food, toilet paper, tissue paper, etc.
# 3                                            2.True  \
# 5                                            2.True
# 7                                            2.True
# 11                                           2.True
# 12                                           2.True
# 13                                           2.True
# 15                                           2.True
# 18                                           2.True
# 20                                           2.True
# 21                                           2.True
# 25                                           2.True
# 27                                           2.True
# 28                                           2.True
# 31                                           2.True
# 32                                           2.True
# 33                                           2.True
# 34                                           2.True
# 35                                           2.True
# 36                                           2.True
# 39                                           2.True
# 44                                           2.True
# 46                                           2.True
# 47                                           2.True
# 48                                           2.True
#
#    Avoid contact with younger people Avoid contact with older people
# 3                          3.Neither                          2.True  \
# 5                          3.Neither                          2.True
# 7                         4.Not true                          2.True
# 11                         3.Neither                          2.True
# 12                        4.Not true                          2.True
# 13                         3.Neither                       3.Neither
# 15                         3.Neither                       3.Neither
# 18                         3.Neither                          2.True
# 20                         3.Neither                       3.Neither
# 21                         3.Neither                          2.True
# 25                         3.Neither                       3.Neither
# 27                         3.Neither                       3.Neither
# 28                         3.Neither                       3.Neither
# 31                        4.Not true                          2.True
# 32                         3.Neither                       3.Neither
# 33                         3.Neither                          2.True
# 34                         3.Neither                       3.Neither
# 35                         3.Neither                          2.True
# 36                         3.Neither                          2.True
# 39                         3.Neither                          2.True
# 44                         3.Neither                       3.Neither
# 46                         3.Neither                       3.Neither
# 47                         3.Neither                       3.Neither
# 48                         3.Neither                          2.True
#
#    Get sufficient rest and sleep Eat a nutritious diet
# 3                    1.Very true           1.Very true  \
# 5                         2.True                2.True
# 7                    1.Very true                2.True
# 11                   1.Very true           1.Very true
# 12                   1.Very true                2.True
# 13                   1.Very true           1.Very true
# 15                   1.Very true           1.Very true
# 18                   1.Very true           1.Very true
# 20                   1.Very true           1.Very true
# 21                   1.Very true           1.Very true
# 25                        2.True                2.True
# 27                   1.Very true           1.Very true
# 28                        2.True                2.True
# 31                   1.Very true           1.Very true
# 32                        2.True                2.True
# 33                   1.Very true           1.Very true
# 34                   1.Very true           1.Very true
# 35                   1.Very true           1.Very true
# 36                   1.Very true           1.Very true
# 39                   1.Very true           1.Very true
# 44                   1.Very true           1.Very true
# 46                   1.Very true           1.Very true
# 47                   1.Very true           1.Very true
# 48                        2.True                2.True
#
#    Do exercise such as jogging or exercise using DVD
# 3                                             2.True
# 5                                          3.Neither
# 7                                          3.Neither
# 11                                            2.True
# 12                                            2.True
# 13                                         3.Neither
# 15                                            2.True
# 18                                            2.True
# 20                                         3.Neither
# 21                                            2.True
# 25                                         3.Neither
# 27                                            2.True
# 28                                         3.Neither
# 31                                            2.True
# 32                                         3.Neither
# 33                                            2.True
# 34                                            2.True
# 35                                            2.True
# 36                                            2.True
# 39                                            2.True
# 44                                            2.True
# 46                                            2.True
# 47                                            2.True
# 48                                         3.Neither
#
# [24 rows x 25 columns]
